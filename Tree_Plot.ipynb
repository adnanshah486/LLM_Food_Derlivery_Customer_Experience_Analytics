# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"  # best for classic Jupyter

data = [
    ("Platform","order",8011),
    ("Restaurant","food",4132),
    ("Rider (Delivery)","delivery",3194),
    ("Rider (Delivery)","time",3113),
    ("Platform","service",2795),
    ("Platform","app",2117),
    ("Rider (Delivery)","driver",1921),
    ("Customer","customer",1874),
    ("Restaurant","item",1596),
    ("Restaurant","restaurant",1578),
    ("Customer","use",1395),
    ("Platform","issue",1288),
    ("Rider (Delivery)","work",998),
    ("Platform","cancel",993),
    ("Platform","charge",983),
    ("Cost","charge",983),
    ("Platform","support",969),
    ("Rider (Delivery)","hour",922),
    ("Customer","eat",896),
    ("Platform","fee",873),
    ("Cost","fee",873),
    ("Restaurant","place",805),
    ("Rider (Delivery)","deliver",796),
    ("Platform","refund",791),
    ("Cost","refund",791),
    ("Platform","way",760),
    ("Platform","option",707),
    ("Customer","get",690),
    ("Platform","help",688),
    ("Platform","problem",628),
    ("Platform","money",609),
    ("Cost","money",609),
    ("Customer","experience",602),
    ("Customer","pay",589),
    ("Cost","pay",589),
    ("Platform","price",557),
    ("Cost","price",557),
    ("Customer","address",522),
    ("Platform","payment",512),
    ("Cost","payment",512),
    ("Customer","try",465),
    ("Restaurant","cold",456),
    ("Customer","show",448),
    ("Platform","contact",436),
    ("Customer","call",430),
    ("Rider (Delivery)","miss",422),
    ("Rider (Delivery)","wait",404),
    ("Customer","thing",401),
    ("Rider (Delivery)","location",398),
    ("Rider (Delivery)","minute",390),
    ("Platform","card",386),
    ("Cost","card",386),
    ("Platform","uber",355),
    ("Customer","phone",343),
    ("Platform","number",338),
    ("Platform","change",334),
    ("Customer","day",318),
    ("Platform","account",314),
    ("Cost","account",314),
    ("Restaurant","quality",312),
    ("Customer","lot",309),
    ("Customer","people",308),
    ("Rider (Delivery)","pick",304),
    ("Platform","message",300),
    ("Platform","amount",278),
    ("Cost","amount",278),
    ("Customer","tip",273),
    ("Cost","tip",273),
    ("Customer","person",267),
    ("Platform","error",263),
    ("Customer","end",254),
    ("Customer","tell",254),
    ("Restaurant","meal",251),
    ("Platform","offer",245),
    ("Cost","offer",245),
    ("Restaurant","store",242),
    ("Platform","system",238),
    ("Platform","credit",232),
    ("Cost","credit",232),
    ("Platform","response",221),
    ("Customer","care",215),
    ("Customer","half",209),
    ("Platform","promotion",202),
    ("Cost","promotion",202),
    ("Platform","notification",199),
    ("Platform","discount",195),
    ("Cost","discount",195),
    ("Restaurant","mess",194),
    ("Platform","cost",190),
    ("Cost","cost",190),
    ("Customer","door",188),
    ("Platform","code",185),
    ("Platform","part",182),
    ("Platform","track",181),
    ("Platform","deal",180),
    ("Cost","deal",180),
    ("Rider (Delivery)","min",177),
    ("Customer","reason",177),
    ("Restaurant","refuse",175),
    ("Platform","instruction",175),
    ("Platform","process",174),
    ("Customer","convenient",166),
    ("Platform","email",165),
    ("Platform","promo",164),
    ("Cost","promo",164),
    ("Rider (Delivery)","area",160),
    ("Restaurant","menu",158),
    ("Rider (Driver)","guy",156),
    ("Customer","ask",154),
    ("Rider (Delivery)","delay",154),
    ("Platform","method",148),
    ("Customer","week",147),
    ("Platform","check",147),
    ("Platform","page",146),
    ("Platform","map",146),
    ("Customer","point",138),
    ("Customer","look",136),
    ("Rider (Delivery)","drop",133),
]

df = pd.DataFrame(data, columns=["Actor","Noun","Freq"])
df["Actor"] = df["Actor"].replace({"Cost": "Payment & Pricing"})


fig = px.treemap(
    df,
    path=["Actor", "Noun"],
    values="Freq",
    color="Actor",
)
fig.update_traces(textinfo="label+value+percent parent")

fig.update_layout(
    title="Perceived quality",
    title_x=0.5,  # center title
    margin=dict(t=60, l=10, r=10, b=10)
)

fig.update_traces(textinfo="label+value+percent parent")
fig.update_layout(margin=dict(t=30, l=10, r=10, b=10))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"  # best for classic Jupyter


data = [
    ("Platform","order",5226),
    ("Rider (Delivery)","delivery",3014),
    ("Restaurant","food",2598),

    ("Platform","fee",2373),
    ("Cost","fee",2373),

    ("Platform","service",2146),
    ("Platform","app",2042),
    ("Rider (Delivery)","time",1866),
    ("Customer","use",1836),

    ("Platform","charge",1766),
    ("Cost","charge",1766),

    ("Platform","price",1393),
    ("Cost","price",1393),

    ("Customer","pay",1361),
    ("Cost","pay",1361),

    ("Platform","money",1258),
    ("Cost","money",1258),

    ("Restaurant","restaurant",1240),
    ("Customer","eat",1141),
    ("Customer","customer",1093),

    ("Platform","refund",1033),
    ("Cost","refund",1033),

    ("Restaurant","item",879),
    ("Rider (Delivery)","driver",788),
    ("Platform","option",745),
    ("Customer","get",657),
    ("Platform","way",649),
    ("Platform","cancel",641),
    ("Platform","issue",630),
    ("Restaurant","place",629),

    ("Platform","discount",609),
    ("Cost","discount",609),

    ("Customer","tip",553),
    ("Cost","tip",553),

    ("Platform","offer",524),
    ("Cost","offer",524),

    ("Rider (Delivery)","work",520),
    ("Platform","support",491),

    ("Platform","cost",479),
    ("Cost","cost",479),

    ("Rider (Delivery)","hour",454),

    ("Platform","amount",445),
    ("Cost","amount",445),

    ("Rider (Delivery)","deliver",405),
    ("Platform","help",390),
    ("Platform","uber",389),

    ("Platform","deal",387),
    ("Cost","deal",387),

    ("Platform","promotion",387),
    ("Cost","promotion",387),

    ("Customer","lot",376),

    ("Platform","payment",374),
    ("Cost","payment",374),

    ("Platform","credit",364),
    ("Cost","credit",364),

    ("Platform","card",353),
    ("Cost","card",353),

    ("Customer","thing",327),
    ("Restaurant","meal",322),
    ("Customer","experience",321),
    ("Customer","try",319),
    ("Platform","problem",316),
    ("Customer","none",313),
    ("Customer","day",312),

    ("Platform","account",294),
    ("Cost","account",294),

    ("Customer","waste",281),
    ("Customer","people",278),

    ("Platform","dollar",278),
    ("Cost","dollar",278),

    ("Customer","end",276),
    ("Restaurant","store",256),
    ("Platform","change",250),

    ("Platform","promo",245),
    ("Cost","promo",245),

    ("Platform","coupon",238),
    ("Cost","coupon",238),

    ("Platform","star",237),
    ("Platform","code",234),
    ("Customer","value",233),
    ("Customer","show",226),
    ("Rider (Delivery)","minute",220),
    ("Rider (Delivery)","pick",217),
    ("Rider (Delivery)","wait",216),
    ("Platform","contact",212),
    ("Customer","door",211),
    ("Customer","address",203),
    ("Customer","reason",202),
    ("Customer","convenience",200),
    ("Customer","worth",199),
    ("Customer","need",188),
    ("Customer","convenient",186),
    ("Platform","company",185),
    ("Platform","number",179),
    ("Customer","call",178),
    ("Customer","pass",177),
    ("Customer","month",176),
    ("Customer","tell",175),
    ("Customer","person",173),
    ("Customer","point",173),
    ("Customer","phone",162),

    ("Platform","subscription",158),
    ("Cost","subscription",158),

    ("Rider (Delivery)","location",157),
    ("Platform","message",155),
    ("Restaurant","refuse",154),
    ("Platform","business",150),
    ("Customer","love",149),

    ("Customer","cash",148),
    ("Cost","cash",148),

    ("Platform","priority",145),
    ("Customer","care",144),
    ("Platform","system",144),
    ("Rider (Delivery)","miss",144),
    ("Restaurant","menu",142),
    ("Customer","ask",141),
    ("Platform","dash",140),
    ("Customer","bit",140),
    ("Rider (Delivery)","area",136),
    ("Customer","choice",135),
    ("Platform","fix",132),
    ("Customer","compare",132),

]

df = pd.DataFrame(data, columns=["Actor","Noun","Freq"])
df["Actor"] = df["Actor"].replace({"Cost": "Payment & Pricing"})


fig = px.treemap(
    df,
    path=["Actor", "Noun"],
    values="Freq",
    color="Actor",
)
fig.update_traces(textinfo="label+value+percent parent")

fig.update_layout(
    title="Perceived value",
    title_x=0.5,  # center title
    margin=dict(t=60, l=10, r=10, b=10)
)

fig.update_traces(textinfo="label+value+percent parent")
fig.update_layout(margin=dict(t=30, l=10, r=10, b=10))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"  # best for classic Jupyter


data = [
    ("Platform","order",2593),
    ("Platform","app",2538),
    ("Platform","service",2482),
    ("Customer","customer",2087),
    ("Rider (Delivery)","delivery",1608),
    ("Restaurant","food",1547),
    ("Customer","use",1473),
    ("Rider (Delivery)","time",1238),
    ("Customer","eat",1165),
    ("Rider (Delivery)","driver",890),
    ("Platform","support",810),
    ("Restaurant","restaurant",764),
    ("Platform","issue",656),
    ("Customer","experience",606),
    ("Customer","none",588),
    ("Platform","way",496),
    ("Platform","help",487),

    ("Platform","money",485),
    ("Cost","money",485),

    ("Platform","company",438),
    ("Platform","option",432),

    ("Platform","fee",420),
    ("Cost","fee",420),

    ("Rider (Delivery)","work",403),
    ("Platform","uber",403),
    ("Restaurant","place",400),

    ("Platform","charge",393),
    ("Cost","charge",393),

    ("Customer","people",378),
    ("Restaurant","item",349),

    ("Platform","refund",346),
    ("Cost","refund",346),

    ("Platform","cancel",333),
    ("Customer","get",310),
    ("Platform","problem",298),
    ("Platform","contact",290),
    ("Customer","thing",263),
    ("Rider (Delivery)","deliver",261),

    ("Customer","pay",260),
    ("Cost","pay",260),

    ("Customer","care",245),
    ("Customer","try",245),
    ("Platform","image",232),
    ("Rider (Delivery)","hour",227),

    ("Platform","price",224),
    ("Cost","price",224),

    ("Platform","number",211),
    ("Platform","star",209),
    ("Customer","call",203),

    ("Platform","offer",194),
    ("Cost","offer",194),

    ("Platform","scam",192),
    ("Platform","business",181),
    ("Customer","lot",178),

    ("Platform","payment",178),
    ("Cost","payment",178),

    ("Customer","day",170),
    ("Customer","show",170),
    ("Customer","address",169),
    ("Customer","phone",165),
    ("Rider (Delivery)","location",163),
    ("Customer","person",161),
    ("Customer","door",159),
    ("Platform","response",153),

    ("Platform","account",149),
    ("Cost","account",149),

    ("Customer","love",148),
    ("Platform","message",144),
    ("Platform","change",143),
    ("Customer","review",140),

    ("Customer","tip",138),
    ("Cost","tip",138),

    ("Customer","need",137),

    ("Platform","card",137),
    ("Cost","card",137),

    ("Customer","look",136),

    ("Platform","deal",133),
    ("Cost","deal",133),

    ("Customer","tell",130),
    ("Customer","mention",126),
    ("Platform","ubereat",125),
    ("Rider (Delivery)","guy",124),
    ("Customer","year",123),
    ("Platform","system",122),
    ("Restaurant","store",118),
    ("Rider (Delivery)","pick",118),
    ("Platform","email",118),
    ("Platform","fix",117),
    ("Platform","recommend",116),
    ("Customer","convenient",116),

    ("Platform","promotion",116),
    ("Cost","promotion",116),

    ("Rider (Delivery)","minute",111),
    ("Customer","waste",111),
    ("Platform","doordash",111),
    ("Rider (Delivery)","area",109),
    ("Rider (Delivery)","wait",108),
    ("Platform","dash",106),
    ("Customer","user",104),

    ("Platform","discount",103),
    ("Cost","discount",103),

    ("Customer","end",102),
    ("Platform","team",102),
    ("Customer","joke",102),
    ("Restaurant","refuse",101),

    ("Platform","amount",100),
    ("Cost","amount",100),

    ("Platform","notification",99),
    ("Customer","feel",98),
    ("Customer","ask",96),
    ("Customer","report",96),
    ("Customer","reason",94),
    ("Customer","talk",93),

    ("Platform","promo",93),
    ("Cost","promo",93),

    ("Customer","complaint",91),
]
df = pd.DataFrame(data, columns=["Actor","Noun","Freq"])
df["Actor"] = df["Actor"].replace({"Cost": "Payment & Pricing"})


fig = px.treemap(
    df,
    path=["Actor", "Noun"],
    values="Freq",
    color="Actor",
)
fig.update_traces(textinfo="label+value+percent parent")

fig.update_layout(
    title="Perceived image",
    title_x=0.5,  # center title
    margin=dict(t=60, l=10, r=10, b=10)
)

fig.update_traces(textinfo="label+value+percent parent")
fig.update_layout(margin=dict(t=30, l=10, r=10, b=10))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"  # best for classic Jupyter


data = [
    ("Platform","order",9309),
    ("Rider (Delivery)","delivery",3788),
    ("Restaurant","food",3644),
    ("Rider (Delivery)","time",3213),
    ("Platform","app",2394),
    ("Platform","service",2226),
    ("Customer","use",2156),
    ("Restaurant","restaurant",2048),

    ("Platform","fee",1692),
    ("Cost","fee",1692),

    ("Restaurant","item",1497),
    ("Rider (Delivery)","driver",1454),
    ("Customer","customer",1419),

    ("Platform","charge",1254),
    ("Cost","charge",1254),

    ("Restaurant","place",1242),
    ("Platform","option",1216),
    ("Customer","eat",1144),
    ("Platform","cancel",1123),
    ("Platform","issue",1027),
    ("Rider (Delivery)","hour",985),

    ("Platform","price",982),
    ("Cost","price",982),

    ("Rider (Delivery)","work",894),

    ("Customer","pay",869),
    ("Cost","pay",869),

    ("Platform","way",861),
    ("Customer","get",795),
    ("Rider (Delivery)","deliver",776),

    ("Platform","payment",678),
    ("Cost","payment",678),

    ("Customer","address",664),
    ("Platform","support",596),

    ("Platform","refund",561),
    ("Cost","refund",561),

    ("Rider (Delivery)","location",557),

    ("Platform","money",549),
    ("Cost","money",549),

    ("Customer","show",542),
    ("Platform","problem",541),
    ("Rider (Delivery)","minute",510),

    ("Platform","card",479),
    ("Cost","card",479),

    ("Platform","change",459),
    ("Customer","try",455),
    ("Customer","thing",449),
    ("Customer","experience",443),

    ("Platform","offer",439),
    ("Cost","offer",439),

    ("Platform","discount",438),
    ("Cost","discount",438),

    ("Platform","help",429),

    ("Platform","promotion",426),
    ("Cost","promotion",426),

    ("Platform","account",399),
    ("Cost","account",399),

    ("Customer","lot",398),
    ("Platform","uber",389),
    ("Platform","number",375),

    ("Platform","amount",368),
    ("Cost","amount",368),

    ("Restaurant","store",364),

    ("Customer","tip",363),
    ("Cost","tip",363),

    ("Rider (Delivery)","wait",359),
    ("Platform","contact",356),
    ("Rider (Delivery)","miss",345),
    ("Rider (Delivery)","pick",338),
    ("Customer","call",338),
    ("Customer","day",337),
    ("Customer","phone",332),

    ("Platform","promo",328),
    ("Cost","promo",328),

    ("Platform","code",318),
    ("Customer","need",298),
    ("Restaurant","meal",297),

    ("Platform","cost",293),
    ("Cost","cost",293),

    ("Customer","person",275),
    ("Customer","people",274),

    ("Platform","deal",272),
    ("Cost","deal",272),

    ("Restaurant","menu",266),
    ("Customer","convenient",259),
    ("Customer","year",255),
    ("Rider (Delivery)","area",245),
    ("Platform","notification",245),

    ("Platform","credit",243),
    ("Cost","credit",243),

    ("Customer","reason",240),
    ("Customer","tell",239),
    ("Customer","month",237),
    ("Platform","error",223),
    ("Customer","door",222),
    ("Platform","message",214),
    ("Customer","half",204),
    ("Customer","end",203),
    ("Platform","method",201),
    ("Platform","star",201),
    ("Restaurant","cold",195),
    ("Rider (Delivery)","min",193),
    ("Customer","estimate",184),
    ("Customer","ask",184),
    ("Platform","email",182),
    ("Platform","system",182),
    ("Platform","list",175),

    ("Platform","dollar",174),
    ("Cost","dollar",174),

    ("Platform","instruction",171),
    ("Platform","process",170),

    ("Platform","coupon",170),
    ("Cost","coupon",170),

    ("Platform","selection",168),
    ("Customer","week",168),
    ("Customer","user",167),

    ("Platform","checkout",158),
    ("Cost","checkout",158),

    ("Platform","search",157),
    ("Rider (Delivery)","delay",153),
    ("Customer","home",153),
    ("Restaurant","grocery",149),
]
df = pd.DataFrame(data, columns=["Actor","Noun","Freq"])
df["Actor"] = df["Actor"].replace({"Cost": "Payment & Pricing"})


fig = px.treemap(
    df,
    path=["Actor", "Noun"],
    values="Freq",
    color="Actor",
)
fig.update_traces(textinfo="label+value+percent parent")

fig.update_layout(
    title="Confirmation of expectations",
    title_x=0.5,  # center title
    margin=dict(t=60, l=10, r=10, b=10)
)

fig.update_traces(textinfo="label+value+percent parent")
fig.update_layout(margin=dict(t=30, l=10, r=10, b=10))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"  # best for classic Jupyter


data = [
    ("Platform","order",7042),
    ("Platform","service",3778),
    ("Platform","app",3645),
    ("Restaurant","food",3353),
    ("Rider (Delivery)","delivery",3123),
    ("Rider (Delivery)","time",2903),
    ("Customer","use",2579),
    ("Customer","customer",2368),
    ("Customer","eat",1480),
    ("Rider (Delivery)","driver",1320),
    ("Restaurant","restaurant",1289),
    ("Customer","experience",1281),
    ("Platform","issue",1260),

    ("Platform","fee",1178),
    ("Cost","fee",1178),

    ("Restaurant","item",1081),

    ("Platform","charge",975),
    ("Cost","charge",975),

    ("Platform","support",962),
    ("Platform","cancel",910),
    ("Rider (Delivery)","work",910),

    ("Platform","refund",875),
    ("Cost","refund",875),

    ("Platform","option",823),
    ("Platform","star",809),

    ("Platform","money",801),
    ("Cost","money",801),

    ("Platform","way",798),
    ("Restaurant","place",766),
    ("Rider (Delivery)","hour",735),
    ("Customer","get",728),

    ("Platform","price",695),
    ("Cost","price",695),

    ("Customer","pay",676),
    ("Cost","pay",676),

    ("Platform","problem",635),
    ("Platform","help",603),
    ("Rider (Delivery)","deliver",585),
    ("Platform","uber",530),
    ("Customer","try",501),

    ("Platform","payment",431),
    ("Cost","payment",431),

    ("Customer","thing",430),
    ("Platform","contact",393),
    ("Customer","day",393),
    ("Customer","address",379),
    ("Rider (Delivery)","wait",366),
    ("Platform","change",364),
    ("Customer","lot",343),

    ("Customer","tip",334),
    ("Cost","tip",334),

    ("Customer","call",314),

    ("Platform","card",306),
    ("Cost","card",306),

    ("Rider (Delivery)","minute",306),
    ("Customer","show",303),
    ("Customer","love",300),

    ("Platform","account",295),
    ("Cost","account",295),

    ("Customer","people",294),
    ("Rider (Delivery)","location",292),

    ("Platform","discount",287),
    ("Cost","discount",287),

    ("Customer","end",285),

    ("Platform","offer",279),
    ("Cost","offer",279),

    ("Customer","phone",267),
    ("Platform","number",265),
    ("Customer","reason",265),
    ("Rider (Delivery)","pick",260),

    ("Platform","credit",259),
    ("Cost","credit",259),

    ("Platform","amount",257),
    ("Cost","amount",257),

    ("Platform","company",255),

    ("Platform","promotion",254),
    ("Cost","promotion",254),

    ("Platform","deal",249),
    ("Cost","deal",249),

    ("Restaurant","store",247),
    ("Restaurant","meal",244),
    ("Rider (Delivery)","miss",244),
    ("Customer","waste",241),

    ("Platform","cost",240),
    ("Cost","cost",240),

    ("Customer","convenient",230),
    ("Customer","need",225),
    ("Customer","person",221),
    ("Platform","fix",219),
    ("Platform","message",214),
    ("Customer","care",208),
    ("Customer","disappoint",208),
    ("Customer","door",208),
    ("Customer","tell",203),
    ("Platform","system",199),
    ("Platform","response",199),
    ("Platform","error",197),
    ("Customer","rate",195),
    ("Platform","code",194),
    ("Platform","notification",190),
    ("Customer","year",186),
    ("Customer","review",186),
    ("Platform","part",183),
    ("Platform","recommend",180),
    ("Customer","month",179),
    ("Customer","week",178),
    ("Restaurant","refuse",174),
    ("Rider (Delivery)","guy",169),
    ("Restaurant","cold",168),
    ("Customer","complaint",168),
    ("Customer","report",167),
    ("Customer","point",166),

    ("Platform","promo",165),
    ("Cost","promo",165),

    ("Customer","ask",163),
    ("Rider (Delivery)","area",158),
    ("Platform","ubereat",157),
    ("Customer","rating",156),
]
df = pd.DataFrame(data, columns=["Actor","Noun","Freq"])
df["Actor"] = df["Actor"].replace({"Cost": "Payment & Pricing"})


fig = px.treemap(
    df,
    path=["Actor", "Noun"],
    values="Freq",
    color="Actor",
)
fig.update_traces(textinfo="label+value+percent parent")

fig.update_layout(
    title="Overall satisfaction",
    title_x=0.5,  # center title
    margin=dict(t=60, l=10, r=10, b=10)
)

fig.update_traces(textinfo="label+value+percent parent")
fig.update_layout(margin=dict(t=30, l=10, r=10, b=10))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"  # best for classic Jupyter


data = [
    ("Platform","order",5169),
    ("Customer","customer",2416),
    ("Platform","service",2131),
    ("Rider (Delivery)","time",2101),
    ("Rider (Delivery)","delivery",1796),
    ("Restaurant","food",1773),
    ("Platform","support",1499),

    ("Platform","refund",1458),
    ("Cost","refund",1458),

    ("Platform","issue",1443),
    ("Platform","app",1427),
    ("Rider (Delivery)","driver",1354),
    ("Restaurant","restaurant",1093),
    ("Platform","help",1004),
    ("Customer","use",973),

    ("Platform","charge",943),
    ("Cost","charge",943),

    ("Customer","eat",938),

    ("Platform","money",924),
    ("Cost","money",924),

    ("Restaurant","item",897),
    ("Platform","cancel",894),
    ("Platform","contact",798),

    ("Platform","fee",798),
    ("Cost","fee",798),

    ("Platform","way",792),
    ("Customer","get",677),
    ("Platform","problem",665),

    ("Customer","pay",585),
    ("Cost","pay",585),

    ("Rider (Delivery)","hour",576),
    ("Platform","option",571),
    ("Customer","call",547),
    ("Restaurant","place",541),
    ("Rider (Delivery)","work",538),
    ("Rider (Delivery)","deliver",488),
    ("Platform","uber",461),

    ("Platform","payment",457),
    ("Cost","payment",457),

    ("Customer","try",453),
    ("Customer","none",442),
    ("Platform","response",439),

    ("Platform","price",418),
    ("Cost","price",418),

    ("Platform","number",417),

    ("Platform","account",405),
    ("Cost","account",405),

    ("Platform","card",390),
    ("Cost","card",390),

    ("Customer","day",389),
    ("Customer","tell",385),
    ("Customer","address",383),
    ("Platform","message",381),
    ("Customer","phone",368),
    ("Customer","care",356),
    ("Customer","people",336),
    ("Customer","thing",326),
    ("Restaurant","refuse",322),

    ("Platform","credit",318),
    ("Cost","credit",318),

    ("Platform","email",305),

    ("Platform","amount",303),
    ("Cost","amount",303),

    ("Customer","show",303),
    ("Customer","person",301),
    ("Platform","change",295),

    ("Customer","tip",280),
    ("Cost","tip",280),

    ("Customer","experience",278),
    ("Rider (Delivery)","wait",274),
    ("Platform","company",255),
    ("Platform","fix",254),
    ("Rider (Delivery)","minute",249),
    ("Customer","trust",249),
    ("Rider (Delivery)","location",248),

    ("Platform","offer",227),
    ("Cost","offer",227),

    ("Platform","discount",222),
    ("Cost","discount",222),

    ("Customer","report",219),
    ("Customer","complaint",216),
    ("Rider (Delivery)","pick",212),
    ("Customer","end",210),
    ("Customer","ask",210),

    ("Platform","promotion",205),
    ("Cost","promotion",205),

    ("Platform","error",198),
    ("Customer","reason",191),
    ("Rider (Delivery)","miss",190),
    ("Restaurant","store",190),
    ("Customer","talk",188),
    ("Platform","system",179),
    ("Customer","need",178),
    ("Platform","team",174),
    ("Platform","notification",167),
    ("Platform","fault",164),
    ("Platform","code",162),

    ("Platform","promo",161),
    ("Cost","promo",161),

    ("Customer","lot",160),
    ("Customer","request",159),
    ("Platform","scam",158),
    ("Restaurant","meal",158),
    ("Rider (Delivery)","guy",157),

    ("Platform","cost",157),
    ("Cost","cost",157),

    ("Platform","respond",152),

    ("Platform","deal",152),
    ("Cost","deal",152),

    ("Platform","reach",136),
    ("Platform","method",136),
    ("Customer","month",136),
    ("Customer","week",134),
    ("Platform","send",133),
    ("Platform","reply",130),
    ("Platform","process",127),

    ("Platform","bank",126),
    ("Cost","bank",126),

    ("Platform","business",125),
]
df = pd.DataFrame(data, columns=["Actor","Noun","Freq"])
df["Actor"] = df["Actor"].replace({"Cost": "Payment & Pricing"})


fig = px.treemap(
    df,
    path=["Actor", "Noun"],
    values="Freq",
    color="Actor",
)
fig.update_traces(textinfo="label+value+percent parent")

fig.update_layout(
    title="Customer trust",
    title_x=0.5,  # center title
    margin=dict(t=60, l=10, r=10, b=10)
)

fig.update_traces(textinfo="label+value+percent parent")
fig.update_layout(margin=dict(t=30, l=10, r=10, b=10))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"  # best for classic Jupyter


data = [
    ("Platform","order",11311),
    ("Restaurant","food",4190),
    ("Rider (Delivery)","time",4111),
    ("Rider (Delivery)","delivery",4043),
    ("Platform","service",2944),
    ("Customer","customer",2652),
    ("Rider (Delivery)","driver",2274),
    ("Platform","app",2259),
    ("Restaurant","restaurant",2206),
    ("Restaurant","item",2202),

    ("Platform","fee",2105),
    ("Cost","fee",2105),

    ("Platform","issue",1912),

    ("Platform","charge",1833),
    ("Cost","charge",1833),

    ("Platform","cancel",1725),

    ("Platform","refund",1650),
    ("Cost","refund",1650),

    ("Customer","use",1635),
    ("Platform","support",1518),
    ("Rider (Delivery)","hour",1401),
    ("Platform","option",1255),
    ("Restaurant","place",1237),
    ("Customer","get",1156),
    ("Platform","way",1136),

    ("Customer","pay",1129),
    ("Cost","pay",1129),

    ("Customer","eat",1127),

    ("Platform","price",1060),
    ("Cost","price",1060),

    ("Platform","money",1025),
    ("Cost","money",1025),

    ("Platform","help",990),
    ("Platform","problem",924),
    ("Rider (Delivery)","deliver",858),
    ("Platform","contact",847),
    ("Rider (Delivery)","work",843),
    ("Customer","try",828),

    ("Platform","payment",801),
    ("Cost","payment",801),

    ("Customer","address",713),
    ("Customer","call",688),
    ("Platform","uber",637),
    ("Customer","thing",605),
    ("Rider (Delivery)","minute",605),

    ("Platform","card",600),
    ("Cost","card",600),

    ("Rider (Delivery)","wait",591),
    ("Rider (Delivery)","location",577),

    ("Customer","tip",568),
    ("Cost","tip",568),

    ("Customer","day",566),
    ("Customer","show",562),
    ("Platform","change",561),
    ("Platform","account",527),
    ("Platform","number",524),

    ("Platform","amount",479),
    ("Cost","amount",479),

    ("Customer","experience",472),
    ("Customer","tell",470),
    ("Customer","complaint",463),
    ("Platform","message",463),
    ("Rider (Delivery)","miss",462),
    ("Customer","phone",459),

    ("Platform","credit",457),
    ("Cost","credit",457),

    ("Rider (Delivery)","pick",441),
    ("Customer","person",411),
    ("Restaurant","store",404),
    ("Customer","end",402),

    ("Platform","discount",394),
    ("Cost","discount",394),

    ("Platform","cost",379),
    ("Cost","cost",379),

    ("Platform","promotion",379),
    ("Cost","promotion",379),

    ("Customer","people",367),

    ("Platform","offer",362),
    ("Cost","offer",362),

    ("Platform","response",362),
    ("Restaurant","refuse",340),
    ("Platform","error",330),
    ("Customer","ask",324),
    ("Customer","lot",324),
    ("Restaurant","meal",321),
    ("Customer","reason",318),
    ("Customer","report",316),
    ("Platform","fix",308),
    ("Platform","code",306),
    ("Restaurant","cold",301),

    ("Platform","promo",301),
    ("Cost","promo",301),

    ("Platform","notification",295),
    ("Customer","need",290),
    ("Customer","care",284),
    ("Platform","email",283),
    ("Customer","half",281),
    ("Platform","system",279),
    ("Restaurant","menu",277),
    ("Customer","none",265),
    ("Platform","star",246),
    ("Platform","method",245),
    ("Customer","door",245),

    ("Platform","deal",244),
    ("Cost","deal",244),

    ("Platform","instruction",243),
    ("Rider (Delivery)","min",235),
    ("Customer","request",229),
    ("Restaurant","mess",226),

    ("Platform","dollar",225),
    ("Cost","dollar",225),

    ("Rider (Delivery)","area",223),
    ("Platform","check",220),
    ("Customer","week",219),
    ("Rider (Delivery)","delay",217),
    ("Rider (Delivery)","guy",212),
    ("Customer","waste",212),
    ("Customer","month",207),
]
df = pd.DataFrame(data, columns=["Actor","Noun","Freq"])
df["Actor"] = df["Actor"].replace({"Cost": "Payment & Pricing"})


fig = px.treemap(
    df,
    path=["Actor", "Noun"],
    values="Freq",
    color="Actor",
)
fig.update_traces(textinfo="label+value+percent parent")

fig.update_layout(
    title="Customer complaints",
    title_x=0.5,  # center title
    margin=dict(t=60, l=10, r=10, b=10)
)

fig.update_traces(textinfo="label+value+percent parent")
fig.update_layout(margin=dict(t=30, l=10, r=10, b=10))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"  # best for classic Jupyter


data = [
    ("Platform","order",3493),
    ("Customer","use",3481),
    ("Platform","app",3397),
    ("Platform","service",2164),
    ("Restaurant","food",1880),
    ("Rider (Delivery)","delivery",1783),
    ("Rider (Delivery)","time",1746),
    ("Customer","eat",1576),
    ("Customer","customer",1312),
    ("Restaurant","restaurant",695),
    ("Customer","experience",671),
    ("Platform","issue",647),

    ("Platform","money",623),
    ("Cost","money",623),

    ("Rider (Delivery)","driver",558),

    ("Platform","fee",527),
    ("Cost","fee",527),

    ("Platform","option",520),
    ("Platform","star",520),
    ("Customer","none",509),
    ("Platform","uber",493),
    ("Rider (Delivery)","work",485),
    ("Platform","way",472),
    ("Platform","cancel",452),
    ("Customer","get",433),
    ("Platform","support",428),

    ("Customer","pay",416),
    ("Cost","pay",416),

    ("Platform","charge",399),
    ("Cost","charge",399),

    ("Restaurant","place",387),
    ("Restaurant","item",366),

    ("Platform","price",310),
    ("Cost","price",310),

    ("Platform","refund",309),
    ("Cost","refund",309),

    ("Platform","problem",308),
    ("Platform","recommend",292),
    ("Customer","year",288),
    ("Customer","try",284),
    ("Customer","thing",282),
    ("Platform","company",279),
    ("Rider (Delivery)","deliver",274),
    ("Platform","help",270),
    ("Customer","lot",266),
    ("Customer","door",265),
    ("Customer","day",252),
    ("Platform","change",247),
    ("Customer","love",245),
    ("Platform","dash",245),
    ("Customer","people",232),
    ("Platform","doordash",231),
    ("Customer","loyalty",224),
    ("Platform","account",218),

    ("Platform","payment",212),
    ("Cost","payment",212),

    ("Rider (Delivery)","hour",210),
    ("Customer","month",207),
    ("Customer","waste",200),

    ("Platform","offer",195),
    ("Cost","offer",195),

    ("Customer","review",194),
    ("Customer","need",194),
    ("Platform","ubereat",191),
    ("Platform","fix",177),
    ("Customer","reason",174),

    ("Platform","discount",172),
    ("Cost","discount",172),

    ("Customer","address",167),

    ("Platform","card",166),
    ("Cost","card",166),

    ("Platform","deal",164),
    ("Cost","deal",164),

    ("Customer","thank",160),
    ("Platform","business",156),
    ("Rider (Delivery)","location",149),

    ("Platform","promotion",149),
    ("Cost","promotion",149),

    ("Rider (Delivery)","pick",146),
    ("Platform","contact",142),
    ("Customer","end",142),

    ("Customer","tip",141),
    ("Cost","tip",141),

    ("Rider (Delivery)","wait",138),
    ("Platform","subscription",137),
    ("Customer","week",132),
    ("Customer","show",131),
    ("Customer","convenient",129),
    ("Platform","number",127),
    ("Customer","care",127),
    ("Customer","phone",125),
    ("Customer","point",124),
    ("Restaurant","meal",123),
    ("Customer","call",122),
    ("Restaurant","store",122),

    ("Platform","cost",121),
    ("Cost","cost",121),

    ("Platform","system",120),
    ("Customer","rating",119),

    ("Platform","amount",119),
    ("Cost","amount",119),

    ("Customer","person",117),
    ("Customer","pass",117),

    ("Platform","credit",116),
    ("Cost","credit",116),

    ("Customer","rate",114),
    ("Customer","user",114),
    ("Customer","stop",113),
    ("Rider (Delivery)","minute",111),
    ("Platform","scam",109),
    ("Rider (Delivery)","guy",109),
    ("Customer","convenience",109),
    ("Customer","mention",107),
    ("Platform","membership",107),
    ("Customer","start",105),
    ("Customer","worth",105),
]
df = pd.DataFrame(data, columns=["Actor","Noun","Freq"])
df["Actor"] = df["Actor"].replace({"Cost": "Payment & Pricing"})


fig = px.treemap(
    df,
    path=["Actor", "Noun"],
    values="Freq",
    color="Actor",
)
fig.update_traces(textinfo="label+value+percent parent")

fig.update_layout(
    title="Customer loyalty",
    title_x=0.5,  # center title
    margin=dict(t=60, l=10, r=10, b=10)
)

fig.update_traces(textinfo="label+value+percent parent")
fig.update_layout(margin=dict(t=30, l=10, r=10, b=10))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
